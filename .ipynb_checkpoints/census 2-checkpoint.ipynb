# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
pd.options.display.max_columns = None

API_KEY = 'aab1e866e5e8fb6435294519ffa9d348d2ee0caf'
BASE_URL = 'https://api.census.gov/data/'

# %%
# get the data from Census API

queries_business_owners = [
    "GEO_ID","NAME","OWNER_VET","OWNER_VET_LABEL","QDESC","QDESC_LABEL","OWNCHAR","OWNCHAR_LABEL","YEAR","OWNPDEMP","OWNPDEMP_F","OWNPDEMP_PCT","OWNPDEMP_PCT_F","OWNPDEMP_S","OWNPDEMP_S_F","OWNPDEMP_PCT_S","OWNPDEMP_PCT_S_F"
]
data_business_owners = requests.get(BASE_URL + '2018/abscbo?get='+ ','.join(queries_business_owners) +'&for=state:*&key=' + API_KEY).json()

# %%
df_business_owners = pd.DataFrame(data_business_owners[1:], columns=data_business_owners[0])
df_business_owners.head()
# Out:
#         GEO_ID         NAME NAICS2017        NAICS2017_LABEL OWNER_SEX  \
# 0  0400000US28  Mississippi        00  Total for all sectors       001
# 1  0400000US28  Mississippi        00  Total for all sectors       001
# 2  0400000US28  Mississippi        00  Total for all sectors       001
# 3  0400000US28  Mississippi        00  Total for all sectors       001
# 4  0400000US28  Mississippi        00  Total for all sectors       001
#
#                   OWNER_SEX_LABEL OWNER_ETH                 OWNER_ETH_LABEL  \
# 0  All owners of respondent firms       001  All owners of respondent firms
# 1  All owners of respondent firms       001  All owners of respondent firms
# 2  All owners of respondent firms       001  All owners of respondent firms
# 3  All owners of respondent firms       001  All owners of respondent firms
# 4  All owners of respondent firms       001  All owners of respondent firms
#
#   OWNER_RACE                OWNER_RACE_LABEL OWNER_VET  \
# 0         00  All owners of respondent firms       001
# 1         00  All owners of respondent firms       001
# 2         00  All owners of respondent firms       001
# 3         00  All owners of respondent firms       001
# 4         00  All owners of respondent firms       001
#
#                   OWNER_VET_LABEL QDESC  QDESC_LABEL OWNCHAR  \
# 0  All owners of respondent firms   O15  PRIORBUSTAT    DIXX
# 1  All owners of respondent firms   O02     YRACQBUS      CG
# 2  All owners of respondent firms   O02     YRACQBUS      CH
# 3  All owners of respondent firms   O02     YRACQBUS      CI
# 4  All owners of respondent firms   O02     YRACQBUS    CI01
#
#        OWNCHAR_LABEL  YEAR OWNPDEMP OWNPDEMP_F OWNPDEMP_PCT OWNPDEMP_PCT_F  \
# 0  Item not reported  2018     1768       None          0.0              X
# 1        Before 1980  2018     1158       None          4.6           None
# 2       1980 to 1989  2018     1978       None          7.8           None
# 3       1990 to 1999  2018     2983       None         11.8           None
# 4       2000 to 2007  2018     5251       None         20.8           None
#
#   OWNPDEMP_S OWNPDEMP_S_F OWNPDEMP_PCT_S OWNPDEMP_PCT_S_F state
# 0       17.7         None            0.0                X    28
# 1       20.3         None            0.9             None    28
# 2       10.0         None            0.9             None    28
# 3       11.7         None            1.0             None    28
# 4        7.0         None            1.6             None    28

# %%
queries_business_summary = [
    "GEO_ID","NAME","NAICS2017","NAICS2017_LABEL","SEX","SEX_LABEL","ETH_GROUP","ETH_GROUP_LABEL","RACE_GROUP","RACE_GROUP_LABEL","VET_GROUP","VET_GROUP_LABEL","EMPSZFI","EMPSZFI_LABEL","YEAR","FIRMPDEMP","FIRMPDEMP_F","EMP","EMP_F","PAYANN","PAYANN_F","FIRMPDEMP_S","FIRMPDEMP_S_F","EMP_S","EMP_S_F","PAYANN_S","PAYANN_S_F"
]
data_business_summary = requests.get(BASE_URL + '2018/abscs?get='+ ','.join(queries_business_summary) +'&for=state:*&key=' + API_KEY).json()

# %%
df_business_summary = pd.DataFrame(data_business_summary[1:], columns=data_business_summary[0])
df_business_summary.head()
# Out:
#         GEO_ID         NAME NAICS2017        NAICS2017_LABEL  SEX SEX_LABEL  \
# 0  0400000US28  Mississippi        00  Total for all sectors  001     Total
# 1  0400000US28  Mississippi        00  Total for all sectors  001     Total
# 2  0400000US28  Mississippi        00  Total for all sectors  001     Total
# 3  0400000US28  Mississippi        00  Total for all sectors  001     Total
# 4  0400000US28  Mississippi        00  Total for all sectors  001     Total
#
#   ETH_GROUP ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL VET_GROUP  \
# 0       029    Non-Hispanic         00            Total       003
# 1       029    Non-Hispanic         00            Total       003
# 2       029    Non-Hispanic         00            Total       003
# 3       029    Non-Hispanic         00            Total       003
# 4       029    Non-Hispanic         00            Total       003
#
#               VET_GROUP_LABEL EMPSZFI                  EMPSZFI_LABEL  YEAR  \
# 0  Equally veteran/nonveteran     612    Firms with 1 to 4 employees  2018
# 1  Equally veteran/nonveteran     620    Firms with 5 to 9 employees  2018
# 2  Equally veteran/nonveteran     630  Firms with 10 to 19 employees  2018
# 3  Equally veteran/nonveteran     641  Firms with 20 to 49 employees  2018
# 4  Equally veteran/nonveteran     642  Firms with 50 to 99 employees  2018
#
#   FIRMPDEMP FIRMPDEMP_F RCPPDEMP RCPPDEMP_F   EMP EMP_F PAYANN PAYANN_F  \
# 0         0           S        0          S     0     g      0        S
# 1       262        None        0          R  1742  None  43830     None
# 2         0           D        0          D     0     g      0        D
# 3         0           D        0          D     0     c      0        D
# 4         0           D        0          D     0     h      0        D
#
#   FIRMPDEMP_S FIRMPDEMP_S_F RCPPDEMP_S RCPPDEMP_S_F EMP_S EMP_S_F PAYANN_S  \
# 0         0.0             S        0.0            S   0.0       S      0.0
# 1        44.0          None        0.0            S  44.5    None     43.5
# 2         0.0             D        0.0            D   0.0       D      0.0
# 3         0.0             D        0.0            D   0.0       D      0.0
# 4         0.0             D        0.0            D   0.0       D      0.0
#
#   PAYANN_S_F YIBSZFI YIBSZFI_LABEL state
# 0          S     001     All firms    28
# 1       None     001     All firms    28
# 2          D     001     All firms    28
# 3          D     001     All firms    28
# 4          D     001     All firms    28

# %%
queries_business_characteristics  = [
    "NAME","GEO_ID","FIRMPDEMP"
]
data_business_characteristics  = requests.get(BASE_URL + '2018/abscb?get='+ ','.join(queries_business_characteristics ) +'&for=state:*&key=' + API_KEY).json()

# %%
df_business_characteristics  = pd.DataFrame(data_business_characteristics [1:], columns=data_business_characteristics [0])
df_business_characteristics.head()
# Out:
#           NAME       GEO_ID FIRMPDEMP state
# 0  Mississippi  0400000US28     40856    28
# 1     Missouri  0400000US29    106753    29
# 2      Montana  0400000US30     31661    30
# 3     Nebraska  0400000US31     43189    31
# 4       Nevada  0400000US32     51758    32

# %%
queries_tech_characteristics  = [
    "NAME","GEO_ID","NAICS2017_LABEL","TECHUSE","FIRMPDEMP"
]
data_tech_characteristics  = requests.get(BASE_URL + '2018/abstcb?get='+ ','.join(queries_tech_characteristics ) +'&for=state:*&key=' + API_KEY).json()

# %%
df_tech_characteristics  = pd.DataFrame(data_tech_characteristics [1:], columns=data_tech_characteristics [0])
df_tech_characteristics.head()
# Out:
#       NAME       GEO_ID   TECHUSE FIRMPDEMP state
# 0  Alabama  0400000US01  T2E03B99     17448    01
# 1  Alabama  0400000US01  T2E03BA9     58136    01
# 2  Alabama  0400000US01  T3E03B01     30912    01
# 3  Alabama  0400000US01  T3E03B02       253    01
# 4  Alabama  0400000US01  T3E03B03      4191    01

# %%
df_business_owners.head()
# Out:
#         GEO_ID         NAME NAICS2017        NAICS2017_LABEL OWNER_SEX  \
# 0  0400000US28  Mississippi        00  Total for all sectors       001
# 1  0400000US28  Mississippi        00  Total for all sectors       001
# 2  0400000US28  Mississippi        00  Total for all sectors       001
# 3  0400000US28  Mississippi        00  Total for all sectors       001
# 4  0400000US28  Mississippi        00  Total for all sectors       001
#
#                   OWNER_SEX_LABEL OWNER_ETH                 OWNER_ETH_LABEL  \
# 0  All owners of respondent firms       001  All owners of respondent firms
# 1  All owners of respondent firms       001  All owners of respondent firms
# 2  All owners of respondent firms       001  All owners of respondent firms
# 3  All owners of respondent firms       001  All owners of respondent firms
# 4  All owners of respondent firms       001  All owners of respondent firms
#
#   OWNER_RACE                OWNER_RACE_LABEL OWNER_VET  \
# 0         00  All owners of respondent firms       001
# 1         00  All owners of respondent firms       001
# 2         00  All owners of respondent firms       001
# 3         00  All owners of respondent firms       001
# 4         00  All owners of respondent firms       001
#
#                   OWNER_VET_LABEL QDESC  QDESC_LABEL OWNCHAR  \
# 0  All owners of respondent firms   O15  PRIORBUSTAT    DIXX
# 1  All owners of respondent firms   O02     YRACQBUS      CG
# 2  All owners of respondent firms   O02     YRACQBUS      CH
# 3  All owners of respondent firms   O02     YRACQBUS      CI
# 4  All owners of respondent firms   O02     YRACQBUS    CI01
#
#        OWNCHAR_LABEL  YEAR OWNPDEMP OWNPDEMP_F OWNPDEMP_PCT OWNPDEMP_PCT_F  \
# 0  Item not reported  2018     1768       None          0.0              X
# 1        Before 1980  2018     1158       None          4.6           None
# 2       1980 to 1989  2018     1978       None          7.8           None
# 3       1990 to 1999  2018     2983       None         11.8           None
# 4       2000 to 2007  2018     5251       None         20.8           None
#
#   OWNPDEMP_S OWNPDEMP_S_F OWNPDEMP_PCT_S OWNPDEMP_PCT_S_F state
# 0       17.7         None            0.0                X    28
# 1       20.3         None            0.9             None    28
# 2       10.0         None            0.9             None    28
# 3       11.7         None            1.0             None    28
# 4        7.0         None            1.6             None    28

# %%
df_business_owners["OWNPDEMP"] = df_business_owners["OWNPDEMP"].astype(int)
df_business_owners["OWNPDEMP_PCT"] = df_business_owners["OWNPDEMP_PCT"].astype(float)
df_business_owners["OWNPDEMP_PCT_S"] = df_business_owners["OWNPDEMP_PCT_S"].astype(float)
df_business_owners["state"] = df_business_owners["state"].astype(int)

# %%
# df_business_summary (Removing total values would break the dataset)
# drop all the total values
# df_business_summary = df_business_summary.drop(df_business_summary[df_business_summary['NAICS2017'] == '00'].index)
# df_business_summary = df_business_summary.drop(df_business_summary[df_business_summary['SEX'] == '001'].index)
# df_business_summary = df_business_summary.drop(df_business_summary[df_business_summary['ETH_GROUP'] == '001'].index)
# df_business_summary = df_business_summary.drop(df_business_summary[df_business_summary['VET_GROUP'] == '001'].index)
# df_business_summary = df_business_summary.drop(df_business_summary[df_business_summary['EMPSZFI'] == '001'].index)

# %%
# Transform the data to their correct types
df_business_summary['FIRMPDEMP'] = df_business_summary['FIRMPDEMP'].astype(int)
df_business_summary['EMP'] = df_business_summary['EMP'].astype(int)
df_business_summary['PAYANN'] = df_business_summary['PAYANN'].astype(int)
df_business_summary['FIRMPDEMP_S'] = df_business_summary['FIRMPDEMP_S'].astype(float)
df_business_summary['EMP_S'] = df_business_summary['EMP_S'].astype(float)
df_business_summary['PAYANN_S'] = df_business_summary['PAYANN_S'].astype(float)
df_business_summary['YEAR'] = df_business_summary['YEAR'].astype(int)
df_business_summary['state'] = df_business_summary['state'].astype(int)

# %%
df_business_characteristics['FIRMPDEMP'] = df_business_characteristics['FIRMPDEMP'].astype(int)
df_business_characteristics['state'] = df_business_characteristics['state'].astype(int)

# %%
df_tech_characteristics['FIRMPDEMP'] = df_tech_characteristics['FIRMPDEMP'].astype(int)
df_tech_characteristics['state'] = df_tech_characteristics['state'].astype(int)

# %%
# what percentage of business owners are
total_number_of_business_owners = df_business_owners['OWNER_VET'].value_counts()
print('The percentage of business owners who are veterans is: ', round((total_number_of_business_owners[1]/total_number_of_business_owners[0])*100,4), '%')
# Out:
# The percentage of business owners who are veterans is:  10.0204 %

# %%
# plot the data as pie chart
labels = 'Veterans', 'Non-Veterans'
sizes = [total_number_of_business_owners[1], total_number_of_business_owners[0]]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# get the data from Census API

# 2. For each state, what is the average salary of employees?
temp_df = df_business_summary.drop(df_business_summary[df_business_summary['EMP'] == 0].index)
temp_df['average_salary'] = temp_df['PAYANN']/temp_df['EMP']
# group by state and get the average salary
average_salary_by_state = temp_df.groupby('NAME')['average_salary'].mean()
average_salary_by_state
# Out:
# NAME
# Alabama                 40.171412
# Alaska                  56.320990
# Arizona                 42.606514
# Arkansas                38.788957
# California              51.910276
# Colorado                48.140857
# Connecticut             54.034079
# Delaware                50.624149
# District of Columbia    68.861020
# Florida                 40.459340
# Georgia                 43.596559
# Hawaii                  45.377049
# Idaho                   36.790130
# Illinois                47.394379
# Indiana                 39.668027
# Iowa                    40.096550
# Kansas                  40.326403
# Kentucky                36.643398
# Louisiana               42.676865
# Maine                   40.747854
# Maryland                50.418356
# Massachusetts           58.780211
# Michigan                44.100340
# Minnesota               46.043570
# Mississippi             34.252976
# Missouri                40.170311
# Montana                 38.090119
# Nebraska                41.232747
# Nevada                  46.534665
# New Hampshire           51.281034
# New Jersey              48.363376
# New Mexico              42.040092
# New York                54.239667
# North Carolina          42.049633
# North Dakota            49.144319
# Ohio                    43.236687
# Oklahoma                42.610122
# Oregon                  42.469796
# Pennsylvania            44.739636
# Rhode Island            44.715530
# South Carolina          38.389113
# South Dakota            38.689216
# Tennessee               39.367834
# Texas                   45.330218
# Utah                    43.340558
# Vermont                 40.960053
# Virginia                62.881006
# Washington              49.028160
# West Virginia           39.139125
# Wisconsin               41.499795
# Wyoming                 45.645732
# Name: average_salary, dtype: float64

# %%
# plot the data using seaborn
plt.figure(figsize=(20,10))
sns.barplot(x=average_salary_by_state.index, y=average_salary_by_state.values)
plt.xticks(rotation=90)
plt.show()

# %%
# 3. For each state, what percentage of total workers belong to each ethnicity?
eth_group_count = df_business_summary.groupby('NAME')['ETH_GROUP_LABEL'].value_counts()
eth_group_count.unstack().fillna(0)
# remove the total values
eth_group_count = eth_group_count.drop(eth_group_count[eth_group_count.index.get_level_values(1) == 'Total'].index)

# %%
# store the total row in a variable
states_total = eth_group_count.unstack().fillna(0).sum(axis=1)
# calculate the percentage
eth_group_count.unstack().fillna(0).div(states_total, axis=0).mul(100).round(2)
# Out:
# ETH_GROUP_LABEL       Non-Hispanic  Hispanic  Classifiable  Unclassifiable  \
# NAME
# Alabama                      47.44     19.74         13.63           10.81
# Alaska                       51.97     15.53         14.74           11.74
# Arizona                      40.37     23.51         11.27            9.68
# Arkansas                     47.84     17.61         13.93           11.90
# California                   36.83     27.98          9.35            8.80
# Colorado                     40.77     23.07         11.17           10.38
# Connecticut                  45.89     20.73         13.25           10.92
# Delaware                     49.25     16.90         14.37           11.01
# District of Columbia         48.21     18.70         13.77           11.69
# Florida                      37.49     27.47          9.75            8.71
# Georgia                      42.69     23.19         11.46           10.43
# Hawaii                       46.29     21.47         12.27            9.58
# Idaho                        45.42     19.52         13.19           10.54
# Illinois                     41.29     24.48         11.50           10.35
# Indiana                      44.71     20.24         12.67           11.33
# Iowa                         47.77     15.74         14.53           12.34
# Kansas                       44.44     21.02         13.18           11.16
# Kentucky                     48.23     16.54         14.12           12.01
# Louisiana                    46.29     19.94         12.87           10.69
# Maine                        48.12     16.52         14.82           12.80
# Maryland                     43.52     21.99         12.15           10.11
# Massachusetts                42.91     21.84         12.20           10.94
# Michigan                     46.24     19.51         12.74           11.09
# Minnesota                    44.74     20.70         12.79           11.16
# Mississippi                  50.60     15.89         14.80           11.84
# Missouri                     44.31     19.82         12.78           11.31
# Montana                      48.73     15.85         14.54           12.59
# Nebraska                     47.33     17.93         14.39           11.70
# Nevada                       43.43     22.39         11.79           10.29
# New Hampshire                48.52     16.51         15.00           11.12
# New Jersey                   41.11     25.19         11.38            9.84
# New Mexico                   39.00     26.59         11.81            9.77
# New York                     40.27     23.26         10.65            9.90
# North Carolina               43.73     23.23         11.87           10.40
# North Dakota                 50.74     14.63         15.32           12.46
# Ohio                         45.71     20.89         13.08           11.70
# Oklahoma                     44.15     20.36         12.32           10.27
# Oregon                       42.94     21.15         12.06           10.41
# Pennsylvania                 43.51     20.87         12.06           10.69
# Rhode Island                 46.41     20.26         13.77           10.78
# South Carolina               45.85     20.61         12.85           10.49
# South Dakota                 49.71     16.96         15.22           12.55
# Tennessee                    44.88     19.06         12.93           11.20
# Texas                        36.92     26.65          9.58            9.14
# Utah                         43.48     22.12         12.24           10.43
# Vermont                      51.25     12.80         16.67           13.39
# Virginia                     43.98     21.27         11.92           10.45
# Washington                   42.15     22.48         11.47           10.03
# West Virginia                50.34     15.00         15.74           11.89
# Wisconsin                    45.98     18.11         13.29           11.90
# Wyoming                      48.20     17.05         14.31           11.03
#
# ETH_GROUP_LABEL       Equally Hispanic/non-Hispanic
# NAME
# Alabama                                        8.38
# Alaska                                         6.02
# Arizona                                       15.17
# Arkansas                                       8.72
# California                                    17.03
# Colorado                                      14.61
# Connecticut                                    9.20
# Delaware                                       8.48
# District of Columbia                           7.64
# Florida                                       16.57
# Georgia                                       12.23
# Hawaii                                        10.39
# Idaho                                         11.32
# Illinois                                      12.38
# Indiana                                       11.05
# Iowa                                           9.64
# Kansas                                        10.20
# Kentucky                                       9.10
# Louisiana                                     10.21
# Maine                                          7.74
# Maryland                                      12.23
# Massachusetts                                 12.12
# Michigan                                      10.42
# Minnesota                                     10.61
# Mississippi                                    6.87
# Missouri                                      11.79
# Montana                                        8.29
# Nebraska                                       8.64
# Nevada                                        12.10
# New Hampshire                                  8.86
# New Jersey                                    12.47
# New Mexico                                    12.83
# New York                                      15.92
# North Carolina                                10.77
# North Dakota                                   6.84
# Ohio                                           8.62
# Oklahoma                                      12.90
# Oregon                                        13.45
# Pennsylvania                                  12.87
# Rhode Island                                   8.78
# South Carolina                                10.20
# South Dakota                                   5.56
# Tennessee                                     11.93
# Texas                                         17.71
# Utah                                          11.73
# Vermont                                        5.89
# Virginia                                      12.37
# Washington                                    13.86
# West Virginia                                  7.03
# Wisconsin                                     10.73
# Wyoming                                        9.41

# %%
# plot the data as bar chart
eth_group_count.unstack().fillna(0).div(states_total, axis=0).mul(100).round(2).plot(kind='bar', stacked=True, figsize=(20,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
# 4. For each state, what is the total number of business and how much average revenue have they generated for 2018?
# total number of business
df_business_summary.groupby('NAME')['FIRMPDEMP'].sum()
# Out:
# NAME
# Alabama                  4717367
# Alaska                    891055
# Arizona                  7503780
# Arkansas                 3080448
# California              57376348
# Colorado                 9941776
# Connecticut              4604667
# Delaware                 1039922
# District of Columbia      831796
# Florida                 34708281
# Georgia                 13065983
# Hawaii                   1490455
# Idaho                    2648610
# Illinois                17712921
# Indiana                  7325650
# Iowa                     4099309
# Kansas                   3635953
# Kentucky                 4228068
# Louisiana                4841019
# Maine                    2042684
# Maryland                 7576862
# Massachusetts            9839239
# Michigan                11885321
# Minnesota                7969419
# Mississippi              2698549
# Missouri                 7674486
# Montana                  1903699
# Nebraska                 2872429
# Nevada                   3481633
# New Hampshire            1857020
# New Jersey              13908643
# New Mexico               1926665
# New York                34201266
# North Carolina          12481684
# North Dakota             1035759
# Ohio                    12616036
# Oklahoma                 4724246
# Oregon                   6425718
# Pennsylvania            15823847
# Rhode Island             1300177
# South Carolina           5532167
# South Dakota             1309853
# Tennessee                6022392
# Texas                   32606715
# Utah                     4658893
# Vermont                   932877
# Virginia                10379757
# Washington              10745836
# West Virginia            1444148
# Wisconsin                7368241
# Wyoming                   875584
# Name: FIRMPDEMP, dtype: int32

# %%
# average revenue
df_business_summary.groupby('NAME')['PAYANN'].mean()
# Out:
# NAME
# Alabama                 4.021929e+05
# Alaska                  7.735732e+04
# Arizona                 5.348340e+05
# Arkansas                2.144009e+05
# California              3.776410e+06
# Colorado                6.173796e+05
# Connecticut             4.828532e+05
# Delaware                1.028983e+05
# District of Columbia    1.687878e+05
# Florida                 1.586902e+06
# Georgia                 8.643846e+05
# Hawaii                  1.223112e+05
# Idaho                   1.306839e+05
# Illinois                1.378745e+06
# Indiana                 6.315578e+05
# Iowa                    3.349926e+05
# Kansas                  2.729495e+05
# Kentucky                3.305172e+05
# Louisiana               3.524479e+05
# Maine                   1.253823e+05
# Maryland                6.657308e+05
# Massachusetts           9.891017e+05
# Michigan                9.384787e+05
# Minnesota               6.501418e+05
# Mississippi             2.051566e+05
# Missouri                5.450941e+05
# Montana                 8.328901e+04
# Nebraska                2.451243e+05
# Nevada                  2.616153e+05
# New Hampshire           1.775264e+05
# New Jersey              1.039753e+06
# New Mexico              1.168993e+05
# New York                2.335114e+06
# North Carolina          8.096355e+05
# North Dakota            9.076539e+04
# Ohio                    1.141583e+06
# Oklahoma                2.984047e+05
# Oregon                  3.959478e+05
# Pennsylvania            1.260518e+06
# Rhode Island            1.174536e+05
# South Carolina          3.631191e+05
# South Dakota            8.443111e+04
# Tennessee               5.326459e+05
# Texas                   2.303239e+06
# Utah                    3.112201e+05
# Vermont                 6.649893e+04
# Virginia                8.443995e+05
# Washington              7.355127e+05
# West Virginia           1.295373e+05
# Wisconsin               7.009959e+05
# Wyoming                 5.554506e+04
# Name: PAYANN, dtype: float64

# %%
# plot the data
df_business_summary.groupby('NAME')['FIRMPDEMP'].sum().plot(kind='bar', figsize=(20,10))
plt.show()

# %%
# 5. The percentage of male and female employees for each state.
gender_group_count = df_business_summary["SEX_LABEL"].value_counts()
gender_group_count
# Out:
# Total                  211234
# Male                    52327
# Female                  39823
# Equally male/female     39307
# Classifiable            15879
# Unclassifiable          13521
# Name: SEX_LABEL, dtype: int64

# %%
# group the number males and females per state
gender_group_count = df_business_summary.groupby('SEX_LABEL')['NAME'].value_counts()
gender_group_count = gender_group_count.unstack().fillna(0).T
total_gender_count = gender_group_count['Total'] - gender_group_count['Classifiable'] - gender_group_count['Unclassifiable']
male_count = gender_group_count['Male'] + gender_group_count['Equally male/female']
female_count = gender_group_count['Female'] + gender_group_count['Equally male/female']

# %%
percent_males = male_count/total_gender_count
percent_females = female_count/total_gender_count
print(f"The percentage of males is: {round(percent_males.mean()*100,2)}%")
print(f"The percentage of females is: {round(percent_females.mean()*100,2)}%")
# Out:
# The percentage of males is: 50.8%
# The percentage of females is: 43.72%

# %%
# plot the data as pie chart
labels = 'Male','Female'
sizes = [percent_males.mean(), percent_females.mean()]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# 6. For each state, the average number of years business have been in business.
df_business_summary['YIBSZFI'].value_counts()
# Out:
# 001    261397
# 323     20123
# 311     19895
# 321     18371
# 322     18070
# 318     17475
# 319     16760
# Name: YIBSZFI, dtype: int64

# %%
df_business_summary['YIBSZFI_LABEL'].value_counts()
# Out:
# All firms                                   261397
# Firms with 16 or more years in business      20123
# Firms with less than 2 years in business     19895
# Firms with 6 to 10 years in business         18371
# Firms with 11 to 15 years in business        18070
# Firms with 2 to 3 years in business          17475
# Firms with 4 to 5 years in business          16760
# Name: YIBSZFI_LABEL, dtype: int64

# %%
# replace the codes with the actual values
# 311 Firms with less than 2 years in business
# 318 Firms with 2 to 3 years in business
# 319 Firms with 4 to 5 years in business
# 321 Firms with 6 to 10 years in business
# 322 Firms with 11 to 15 years in business
# 323 Firms with 16 or more years in business
codes = {
    '311': 1,
    '318': 2.5,
    '319': 4.5,
    '321': 8,
    '322': 13,
    '323': 16,
    '001': 'Total'
}
df_years_in_business = df_business_summary.replace({'YIBSZFI': codes})
# remove the total row
df_years_in_business = df_years_in_business.drop(df_years_in_business[df_years_in_business['YIBSZFI'] == 'Total'].index)

df_years_in_business.groupby('NAME')['YIBSZFI'].mean()
# Out:
# NAME
# Alabama                 7.661427
# Alaska                  7.755139
# Arizona                 7.545341
# Arkansas                7.612669
# California              7.530547
# Colorado                7.528968
# Connecticut             7.589961
# Delaware                7.447656
# District of Columbia    7.579247
# Florida                 7.496253
# Georgia                 7.547336
# Hawaii                  7.717073
# Idaho                   7.683010
# Illinois                7.559820
# Indiana                 7.618694
# Iowa                    7.666246
# Kansas                  7.778987
# Kentucky                7.641969
# Louisiana               7.694494
# Maine                   7.751949
# Maryland                7.561538
# Massachusetts           7.639816
# Michigan                7.586484
# Minnesota               7.553149
# Mississippi             7.638875
# Missouri                7.614253
# Montana                 7.647833
# Nebraska                7.656439
# Nevada                  7.494655
# New Hampshire           7.850000
# New Jersey              7.527292
# New Mexico              7.680803
# New York                7.540752
# North Carolina          7.622227
# North Dakota            7.586490
# Ohio                    7.632030
# Oklahoma                7.676813
# Oregon                  7.547578
# Pennsylvania            7.609560
# Rhode Island            7.682786
# South Carolina          7.523746
# South Dakota            7.748878
# Tennessee               7.536034
# Texas                   7.515517
# Utah                    7.581517
# Vermont                 7.844615
# Virginia                7.602923
# Washington              7.609761
# West Virginia           7.845218
# Wisconsin               7.547652
# Wyoming                 7.563078
# Name: YIBSZFI, dtype: float64

# %%
# plot the data as chart showing the average number of years in business
df_years_in_business.groupby('NAME')['YIBSZFI'].mean().plot(kind='bar', figsize=(20,10))
plt.show()

# %%
# generate heatmap showing correlation between the data to see how company size, company revenue, employee type (gender, veterans, etc.), company location and company years active are correlated
corr = df_business_summary.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(data = corr,
annot = True,
mask = mask,
cmap = 'PuBuGn_r',
vmin = -1,
vmax = 1)
# Out:
# C:\Users\acelx\AppData\Local\Temp\ipykernel_23932\2334967259.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_business_summary.corr()
# <AxesSubplot: >
